# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np
from scipy.stats import linregress
import json
import requests
import seaborn as sns
import petpy as petpy 
import datetime as date
from config import api_key
from config import client_secret

# %%
pf  = petpy.Petfinder(key=api_key, secret=client_secret)

dogs = pf.animals(animal_type='dog', results_per_page=100, pages=40, return_df=True, location='Chicago, Illinois')
dogs
# Out:
#             id  organization_id  \
# 0     69340179            IL879
# 1     69339980            WI506
# 2     69339915            WI472
# 3     69339904            IL905
# 4     69339877            IL566
# ...        ...              ...
# 3995  60368421            IL275
# 3996  60365967            IL666
# 3997  60365452            IL703
# 3998  60267962            IL979
# 3999  60261648            IL267
#
#                                                     url type species     age  \
# 0     https://www.petfinder.com/dog/little-man-69340...  Dog     Dog   Young
# 1     https://www.petfinder.com/dog/cobi-69339980/wi...  Dog     Dog  Senior
# 2     https://www.petfinder.com/dog/ice-475-dollars-...  Dog     Dog    Baby
# 3     https://www.petfinder.com/dog/apple-69339904/i...  Dog     Dog    Baby
# 4     https://www.petfinder.com/dog/hershey-69339877...  Dog     Dog    Baby
# ...                                                 ...  ...     ...     ...
# 3995  https://www.petfinder.com/dog/oreo-60368421/il...  Dog     Dog   Adult
# 3996  https://www.petfinder.com/dog/donny-angel-6036...  Dog     Dog  Senior
# 3997  https://www.petfinder.com/dog/harrison-ford-60...  Dog     Dog   Young
# 3998  https://www.petfinder.com/dog/charlotte-aka-ch...  Dog     Dog   Adult
# 3999  https://www.petfinder.com/dog/grady-60261648/i...  Dog     Dog    Baby
#
#       gender    size    coat  \
# 0       Male   Small   Short
# 1       Male   Small  Medium
# 2     Female  Medium    None
# 3       Male   Small    None
# 4       Male  Medium  Medium
# ...      ...     ...     ...
# 3995    Male   Large   Short
# 3996    Male   Small    None
# 3997    Male  Medium    None
# 3998  Female  Medium   Short
# 3999    Male  Medium    None
#
#                                                    tags  ...  \
# 0     [Friendly, Affectionate, Gentle, Playful, Brav...  ...
# 1                                                    []  ...
# 2                                                    []  ...
# 3                                                    []  ...
# 4                                                    []  ...
# ...                                                 ...  ...
# 3995                         [Playful, Gentle, Curious]  ...
# 3996  [Friendly, Gentle, Curious, Funny, Quiet, Affe...  ...
# 3997                                                 []  ...
# 3998  [Friendly, Playful, Affectionate, Curious, Smart]  ...
# 3999                                                 []  ...
#
#      contact.address.address1 contact.address.address2 contact.address.city  \
# 0                        None                     None               Aurora
# 1                        None                     None           Whitewater
# 2           4525 W BURNHAM ST                     None            Milwaukee
# 3                        None                     None          St. Charles
# 4                        None                     None               Gurnee
# ...                       ...                      ...                  ...
# 3995            P. O. Box 284           Peru, IL 61354             La Salle
# 3996  3124 W. Irving Park Rd.                     None              Chicago
# 3997        372 Townline Road                     None            Mundelein
# 3998         12305 S. New Ave                     None               Lemont
# 3999                     None                     None         West Chicago
#
#      contact.address.state contact.address.postcode contact.address.country  \
# 0                       IL                    60506                      US
# 1                       WI                    53190                      US
# 2                       WI                    53202                      US
# 3                       IL                    60175                      US
# 4                       IL                    60031                      US
# ...                    ...                      ...                     ...
# 3995                    IL                    61301                      US
# 3996                    IL                    60640                      US
# 3997                    IL                    60060                      US
# 3998                    IL                    60439                      US
# 3999                    IL                    60185                      US
#
#      animal_id animal_type  organization_id primary_photo_cropped
# 0     69340179         dog            il879                   NaN
# 1     69339980         dog            wi506                   NaN
# 2     69339915         dog            wi472                   NaN
# 3     69339904         dog            il905                   NaN
# 4     69339877         dog            il566                   NaN
# ...        ...         ...              ...                   ...
# 3995  60368421         dog            il275                   NaN
# 3996  60365967         dog            il666                   NaN
# 3997  60365452         dog            il703                   NaN
# 3998  60267962         dog            il979                   NaN
# 3999  60261648         dog            il267                   NaN
#
# [4000 rows x 50 columns]

# %%
dogs.columns

dogs.tags.value_counts()
# Out:
# tags
# []                                                                                             2477
# [Friendly, Affectionate]                                                                         60
# [Friendly, Affectionate, Playful]                                                                31
# [Friendly, Playful]                                                                              16
# [Friendly, Affectionate, Playful, Funny, Loves Kisses]                                           15
#                                                                                                ...
# [Friendly, Affectionate, Playful, Smart, Curious]                                                 1
# [Friendly, Gentle, Playful, Quiet, Couch potato, Loves Kisses]                                    1
# [Gentle, Affectionate, Playful, Smart, Loyal, Protective, Funny, Loves kisses, Independent]       1
# [Friendly, Affectionate, Playful, Smart, Curious, Loves kisses, Athletic, Funny]                  1
# [Friendly, Playful, Affectionate, Curious, Smart]                                                 1
# Name: count, Length: 1067, dtype: int64

# %%
df = dogs[['id', 'organization_id', 'url', 'species', 'age', 'gender',
       'size', 'coat', 'tags', 'name', 'description', 'organization_animal_id',
       'photos', 'status', 'status_changed_at', 'published_at',
       'distance', 'breeds.primary', 'breeds.secondary', 'breeds.mixed',
       'breeds.unknown', 'colors.primary', 'colors.secondary',
       'colors.tertiary','attributes.special_needs', 'attributes.shots_current',
       'environment.children', 'environment.dogs', 'environment.cats',
       'contact.address.address1',
       'contact.address.address2', 'contact.address.city',
       'contact.address.state', 'contact.address.postcode',
       'contact.address.country', 'animal_id', 'animal_type',
       'organization_id']]

# %%
df.to_csv("Datasets/petfinder_dog_data.csv")
